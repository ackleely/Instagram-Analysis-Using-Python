# %% [markdown]
# # **Instagram Analysis Using Python**

# %% [markdown]
# Python data analysis for Instagram is a potent tool for learning about user behavior, industry trends, and content performance. Utilize data scraping from Instagram profiles, posts, and comments to gain insight into the preferences actions, and interests of your audience. Utilize metrics like follower numbers engagement rate, and content relevancy to identify possible influencers. This is a list of the top 50 accounts on Instagram, a photo and video sharing social network.

# %% [markdown]
# #**Import Library**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Uploading Csv fle**

# %%
df = pd.read_csv("/content/07_Instagram Analysis.csv")

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# # **.head()**

# %%
df.head()
# Out:
#    Rank      Username              Owner  Followers(millions)  \
# 0     1    @instagram          Instagram                645.0
# 1     2    @cristiano  Cristiano Ronaldo                594.0
# 2     3     @leomessi       Lionel Messi                476.0
# 3     4  @selenagomez       Selena Gomez                423.0
# 4     5  @kyliejenner       Kylie Jenner                395.0
#
#                         Profession/Activity        Country
# 0                     Social media platform  United States
# 1                                Footballer       Portugal
# 2                                Footballer      Argentina
# 3      Musician, actress, and businesswoman  United States
# 4  Television personality and businesswoman  United States

# %% [markdown]
# # **.tail()**

# %%
df.tail()
# Out:
#     Rank         Username          Owner  Followers(millions)  \
# 45    46       @snoopdogg     Snoop Dogg                 80.0
# 46    47    @davidbeckham  David Beckham                 79.3
# 47    48  @jennierubyjane         Jennie                 79.1
# 48    49         @khaby00     Khaby Lame                 79.1
# 49    50       @gigihadid     Gigi Hadid                 78.5
#
#                                   Profession/Activity         Country
# 45                                           Musician   United States
# 46  Former footballer, president of MLS club Inter...  United Kingdom
# 47                                           Musician     South Korea
# 48                           Social media personality   Italy Senegal
# 49                                              Model   United States

# %% [markdown]
# # **.shape**

# %%
df.shape
# Out:
# (50, 6)

# %% [markdown]
# # **.columns**

# %%
df.columns
# Out:
# Index(['Rank', 'Username', 'Owner', 'Followers(millions)',
#        'Profession/Activity', 'Country'],
#       dtype='object')

# %% [markdown]
# # **.dtypes**

# %%
df.dtypes
# Out:
# Rank                     int64
# Username                object
# Owner                   object
# Followers(millions)    float64
# Profession/Activity     object
# Country                 object
# dtype: object

# %% [markdown]
# # **.unique()**

# %%
df["Country"].unique()
# Out:
# array(['United States', 'Portugal', 'Argentina', 'Canada', 'India',
#        'Trinidad and Tobago\xa0United States', 'Brazil', 'Barbados',
#        'Spain', 'Europe', 'France', 'Israel', 'Thailand',
#        'United Kingdom\xa0Albania', 'Colombia', 'United States\xa0Canada',
#        'United Kingdom', 'South Korea', 'Italy\xa0Senegal'], dtype=object)

# %% [markdown]
# # **.nuique()**

# %%
df.nunique()
# Out:
# Rank                   50
# Username               50
# Owner                  50
# Followers(millions)    47
# Profession/Activity    30
# Country                19
# dtype: int64

# %% [markdown]
# # **.describe()**

# %%
df.describe()
# Out:
#            Rank  Followers(millions)
# count  50.00000            50.000000
# mean   25.50000           208.976000
# std    14.57738           136.262332
# min     1.00000            78.500000
# 25%    13.25000            96.850000
# 50%    25.50000           161.000000
# 75%    37.75000           288.000000
# max    50.00000           645.000000

# %% [markdown]
# # **.value_counts()**

# %%
df["Country"].value_counts()
# Out:
# Country
# United States                        28
# India                                 3
# Canada                                2
# Spain                                 2
# Israel                                1
# South Korea                           1
# United Kingdom                        1
# United States Canada                  1
# Colombia                              1
# United Kingdom Albania                1
# Thailand                              1
# Europe                                1
# France                                1
# Portugal                              1
# Barbados                              1
# Brazil                                1
# Trinidad and Tobago United States     1
# Argentina                             1
# Italy Senegal                         1
# Name: count, dtype: int64

# %% [markdown]
# # **.isnull**

# %%
df.isnull()
# Out:
#      Rank  Username  Owner  Followers(millions)  Profession/Activity  Country
# 0   False     False  False                False                False    False
# 1   False     False  False                False                False    False
# 2   False     False  False                False                False    False
# 3   False     False  False                False                False    False
# 4   False     False  False                False                False    False
# 5   False     False  False                False                False    False
# 6   False     False  False                False                False    False
# 7   False     False  False                False                False    False
# 8   False     False  False                False                False    False
# 9   False     False  False                False                False    False
# 10  False     False  False                False                False    False
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df["Followers(millions)"] = pd.to_numeric(df["Followers(millions)"], errors="coerce")
print(df)
# Out:
#     Rank             Username                  Owner  Followers(millions)  \
# 0      1           @instagram              Instagram                645.0
# 1      2           @cristiano      Cristiano Ronaldo                594.0
# 2      3            @leomessi           Lionel Messi                476.0
# 3      4         @selenagomez           Selena Gomez                423.0
# 4      5         @kyliejenner           Kylie Jenner                395.0
# 5      6             @therock         Dwayne Johnson                385.0
# 6      7        @arianagrande          Ariana Grande                375.0
# 7      8       @kimkardashian         Kim Kardashian                360.0
# 8      9             @beyonce                Beyoncé                312.0
# 9     10     @khloekardashian       Khloé Kardashian                309.0
# 10    11                @nike                   Nike                299.0
# 11    12        @justinbieber          Justin Bieber                292.0
# ...

# %%
df_usa = df[df['Country'] == 'United States']
print(df)
# Out:
#     Rank             Username                  Owner  Followers(millions)  \
# 0      1           @instagram              Instagram                645.0
# 1      2           @cristiano      Cristiano Ronaldo                594.0
# 2      3            @leomessi           Lionel Messi                476.0
# 3      4         @selenagomez           Selena Gomez                423.0
# 4      5         @kyliejenner           Kylie Jenner                395.0
# 5      6             @therock         Dwayne Johnson                385.0
# 6      7        @arianagrande          Ariana Grande                375.0
# 7      8       @kimkardashian         Kim Kardashian                360.0
# 8      9             @beyonce                Beyoncé                312.0
# 9     10     @khloekardashian       Khloé Kardashian                309.0
# 10    11                @nike                   Nike                299.0
# 11    12        @justinbieber          Justin Bieber                292.0
# ...

# %% [markdown]
# # **Visualization**

# %%
Country = df['Country'].value_counts()

# %%
Country
# Out:
# Country
# United States                        28
# India                                 3
# Canada                                2
# Spain                                 2
# Israel                                1
# South Korea                           1
# United Kingdom                        1
# United States Canada                  1
# Colombia                              1
# United Kingdom Albania                1
# Thailand                              1
# Europe                                1
# France                                1
# Portugal                              1
# Barbados                              1
# Brazil                                1
# Trinidad and Tobago United States     1
# Argentina                             1
# Italy Senegal                         1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.title("Country")
sns.countplot(x=df["Country"]);
plt.xticks(rotation=90);

# %%
Profession = df['Profession/Activity'].value_counts()
Profession
# Out:
# Profession/Activity
# Musician                                                   12
# Musician and actress                                        4
# Footballer                                                  3
# Television personality and model                            2
# Actress                                                     2
# Musician and businesswoman                                  2
# Football club                                               2
# Club football competition                                   1
# Footballer at Paris Saint-Germain                           1
# Social media platform                                       1
# Actor                                                       1
# Space agency                                                1
# Actress and musician                                        1
# Professional basketball league                              1
# Former footballer, president of MLS club Inter Miami CF     1
# ...

# %%
plt.subplots(figsize=(15,10))
plt.title("Activity")
sns.countplot(x=df["Profession/Activity"]);
plt.xticks(rotation=90);

# %%
top10_influenceur= df.drop([ 'Owner', 'Profession/Activity', 'Country'], axis=1)
top10=top10_influenceur.head(10)

# %%
top10
# Out:
#    Rank          Username  Followers(millions)
# 0     1        @instagram                645.0
# 1     2        @cristiano                594.0
# 2     3         @leomessi                476.0
# 3     4      @selenagomez                423.0
# 4     5      @kyliejenner                395.0
# 5     6          @therock                385.0
# 6     7     @arianagrande                375.0
# 7     8    @kimkardashian                360.0
# 8     9          @beyonce                312.0
# 9    10  @khloekardashian                309.0

# %%
plt.figure(figsize=(10,10))
plt.pie(top10['Followers(millions)'],shadow = True, labels=top10["Username"],autopct = "%0.2f%%")
plt.show()
